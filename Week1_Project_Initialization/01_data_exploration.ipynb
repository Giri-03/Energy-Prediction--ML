# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/cleaned_co2_data.csv")

# Quick look
df.info()
print(df.describe())

# Simple plots
df.hist(figsize=(10,6))
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18646 entries, 0 to 18645
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   entity                          18646 non-null  object
#  1   code                            18646 non-null  object
#  2   year                            18646 non-null  int64
#  3   annual co₂ emissions (tonnes )  18646 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 582.8+ KB
#                year  annual co₂ emissions (tonnes )
# count  18646.000000                    1.864600e+04
# mean    1961.144374                    1.665738e+08
# std       49.510687                    1.382420e+09
# min     1751.000000                    0.000000e+00
# 25%     1945.000000                    4.506720e+05
# 50%     1974.000000                    3.997712e+06
# 75%     1996.000000                    3.287222e+07
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/raw/co2_emission_data.csv")  # adjust filename if different
print(df.head())
print(df.info())
# Out:
#         Entity Code  Year  Annual CO₂ emissions (tonnes )
# 0  Afghanistan  AFG  1949                         14656.0
# 1  Afghanistan  AFG  1950                         84272.0
# 2  Afghanistan  AFG  1951                         91600.0
# 3  Afghanistan  AFG  1952                         91600.0
# 4  Afghanistan  AFG  1953                        106256.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20853 entries, 0 to 20852
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Entity                          20853 non-null  object
#  1   Code                            18646 non-null  object
#  2   Year                            20853 non-null  int64
#  3   Annual CO₂ emissions (tonnes )  20853 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 651.8+ KB
# None
